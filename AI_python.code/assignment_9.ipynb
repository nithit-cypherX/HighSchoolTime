# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %%
data = pd.read_excel('stdScores.xlsx')
data
# Out:
#      #  รหัสนักศึกษา  Attendances I (10)  Attendances II (5)  ...  28  29  30  Total
# 0    1    5410110014                 8.0                 2.0  ... NaN NaN NaN    NaN
# 1    2    5410110026                 9.0                 5.0  ... NaN NaN NaN    NaN
# 2    3    5410110034                10.0                 5.0  ... NaN NaN NaN    NaN
# 3    4    5410110035                10.0                 5.0  ... NaN NaN NaN    NaN
# 4    5    5410110063                10.0                 5.0  ... NaN NaN NaN    NaN
# ..  ..           ...                 ...                 ...  ...  ..  ..  ..    ...
# 61  62    5410110633                 8.0                 5.0  ... NaN NaN NaN    NaN
# 62  63    5410110643                10.0                 5.0  ... NaN NaN NaN    NaN
# 63  64    5410110655                 7.0                 3.0  ... NaN NaN NaN    NaN
# 64  65    5410110660                 5.0                 5.0  ... NaN NaN NaN    NaN
# ...

# %% [markdown]
# ข้อ 1

# %%
df = data[['รหัสนักศึกษา','Midterm Grade']]
df.set_index('Midterm Grade',inplace= True)
a =df.filter(regex='E',axis=0)
a
# Out:
#                รหัสนักศึกษา
# Midterm Grade
# E                5410110014
# E                5410110075
# E                5410110079
# E                5410110161
# E                5410110174
# E                5410110210
# E                5410110221
# E                5410110238
# E                5410110291
# E                5410110305
# E                5410110323
# E                5410110386
# E                5410110403
# E                5410110415
# E                5410110436
# E                5410110567
# E                5410110588
# E                5410110615
# E                5410110643
# E                5410110655
# E                5410110660

# %% [markdown]
# ข้อ 2

# %%
b = data[['รหัสนักศึกษา','Quiz (50)','Quiz (15%)','Midterm (100)','Midterm (30%)']]
b.set_index('รหัสนักศึกษา',inplace= True)
pd.set_option('display.max_rows', b.shape[0]+1)
b.replace({"ขาดสอบ":np.nan,"ลากิจ":np.nan},regex= True,inplace= True)
b.fillna(np.nan,inplace=True)

b[pd.isnull(b).any(axis=1)]
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
#               Quiz (50)  Quiz (15%)  Midterm (100)  Midterm (30%)
# รหัสนักศึกษา
# 5410110238          NaN         NaN            NaN            NaN
# 5410110323          NaN         NaN            NaN            NaN
# 5410110405          NaN         NaN           56.0           16.8

# %% [markdown]
# ข้อ3

# %%
data.describe()
# Out:
#                #  รหัสนักศึกษา  Attendances I (10)  ...   29   30  Total
# count  66.000000  6.600000e+01           64.000000  ...  0.0  0.0    0.0
# mean   33.500000  5.410110e+09            9.140625  ...  NaN  NaN    NaN
# std    19.196354  1.922443e+02            1.270760  ...  NaN  NaN    NaN
# min     1.000000  5.410110e+09            5.000000  ...  NaN  NaN    NaN
# 25%    17.250000  5.410110e+09            8.000000  ...  NaN  NaN    NaN
# 50%    33.500000  5.410110e+09           10.000000  ...  NaN  NaN    NaN
# 75%    49.750000  5.410111e+09           10.000000  ...  NaN  NaN    NaN
# max    66.000000  5.410111e+09           10.000000  ...  NaN  NaN    NaN
#
# [8 rows x 21 columns]

# %% [markdown]
# ข้อ 4

# %%
c = data[['Midterm Grade']]

c.apply(pd.value_counts).plot(kind="bar",subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f978060b4a8>],
#       dtype=object)

# %% [markdown]
# ข้อ 5

# %%
d =data['Total (50%)']
plt.plot(d)
plt.xlabel('studenr order')
plt.ylabel("scores")
# Out:
# Text(0, 0.5, 'scores')
